# %%
item1 = 'snicker'
price1 = 2

item2 = 'water'
price2 = 1

item3 = 'fanta'
price3 = 3

item4 = 'lays'
price4 = 5

item5 = 'holsten'
price5 = 6.5

item6 = 'code red'
price6 = 5



item = input('enter the desired product:')

if item == item1:
    cash = int(input('insert cash'))

    if cash >= price1:
        print("thank you for your purchase")
    else:
        print('incorrect amount')
        

elif item == item2:
    cash = int(input('insert cash'))

    if cash >= price2:
        print("thank you for your purchase")
    else:
        print('incorrect amount')
        

elif item == item3:
    cash = int(input('insert cash'))

    if cash >= price3:
        print("thank you for your purchase")
    else:
        print('incorrect amount')

    
        
elif item == item4:
    cash = int(input('insert cash'))

    if cash >= price4:
        print("thank you for your purchase")
    else:
        print('incorrect amount')
        

elif item == item5:
    cash = float(input('insert cash'))

    if cash >= price5:
        print("thank you for your purchase")
    else:
        print('incorrect amount')


elif item == item6:
    cash = int(input('insert cash'))

    if cash >= price6:
        print('thank you for your purchase')

    else:
        print('incorrect amount')
# Out:
# enter the desired product: code red
# insert cash 5
# thank you for your purchase
